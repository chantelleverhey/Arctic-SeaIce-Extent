# %%
print ("Hello, World")
# Out:
# Hello, World

# %%
# EDC libraries
from edc import setup_environment_variables

# Utilities
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Image

# Sentinel Hub
from sentinelhub import (MimeType, CRS, BBox, SentinelHubRequest, SentinelHubDownloadClient, 
                         DataCollection, bbox_to_dimensions, DownloadRequest, SHConfig)

# %%
import requests

response = requests.post('https://services.sentinel-hub.com/api/v1/process',
  headers={"Authorization" : "Bearer <your_access_token>"},
  json={
    "input": {
        "bounds": {
            "bbox": [
                -96.064108,
                68.569211,
                -95.622594,
                68.671589
            ]
        },
        "data": [{
            "type": "sentinel-2-l2a"
        }]
    },
    "evalscript": """
    //VERSION=3

    function setup() {
      return {
        input: ["B02", "B03", "B04"],
        output: {
          bands: 3
        }
      };
    }

    function evaluatePixel(
      sample,
      scenes,
      inputMetadata,
      customData,
      outputMetadata
    ) {
      return [2.5 * sample.B04, 2.5 * sample.B03, 2.5 * sample.B02];
    }
    """
})

# %%
# Pass Sentinel Hub credentials to SHConfig
config = SHConfig()
config.sh_client_id = os.environ["SH_CLIENT_ID"]
config.sh_client_secret = os.environ["SH_CLIENT_SECRET"]

# %%
# Define the plot_image function
def plot_image(image, factor=1.0, clip_range = None, **kwargs):
    """
    Utility function for plotting RGB images.
    """
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
    if clip_range is not None:
        ax.imshow(np.clip(image * factor, *clip_range), **kwargs)
    else:
        ax.imshow(image * factor, **kwargs)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# Configure plots for inline use in Jupyter Notebook
# %matplotlib inline

# %%
Gjao_coords_wgs84 = [-96.064108,68.569211,-95.622594,68.671589]

# %%
resolution = 60
Gjao_bbox = BBox(bbox=Gjao_coords_wgs84, crs=CRS.WGS84)
Gjao_size = bbox_to_dimensions(Gjao_bbox, resolution=resolution)

print(f'Image shape at {resolution} m resolution: {Gjao_size} pixels')
# Out:
# Image shape at 60 m resolution: (308, 176) pixels

# %%
evalscript_true_color = """
    //VERSION=3

    function setup() {
        return {
            input: [{
                bands: ["B02", "B03", "B04"]
            }],
            output: {
                bands: 3
            }
        };
    }

    function evaluatePixel(sample) {
        return [sample.B04, sample.B03, sample.B02];
    }
"""

request_true_color = SentinelHubRequest(
    evalscript=evalscript_true_color,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L1C,
            time_interval=('2020-06-12', '2020-06-13'),
        )
    ],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.PNG)
    ],
    bbox=Gjao_bbox,
    size=Gjao_size,
    config=config
)

# %%
true_color_imgs = request_true_color.get_data()

# %%
print(f'Returned data is of type = {type(true_color_imgs)} and length {len(true_color_imgs)}.')
print(f'Single element in the list is of type {type(true_color_imgs[-1])} and has shape {true_color_imgs[-1].shape}')
# Out:
# Returned data is of type = <class 'list'> and length 1.
# Single element in the list is of type <class 'numpy.ndarray'> and has shape (176, 308, 3)

# %%
image = true_color_imgs[0]
print(f'Image type: {image.dtype}')

# plot function
# factor 1/255 to scale between 0-1
# factor 3.5 to increase brightness
plot_image(image, factor=3.5/255, clip_range=(0,1))
# Out:
# Image type: uint8

# %%
evalscript_clm = """
//VERSION=3
function setup() {
  return {
    input: ["B02", "B03", "B04", "CLM"],
    output: { bands: 3 }
  }
}

function evaluatePixel(sample) {
  if (sample.CLM == 1) {
    return [0.75 + sample.B04, sample.B03, sample.B02]
  }
  return [3.5*sample.B04, 3.5*sample.B03, 3.5*sample.B02];
}
"""

request_true_color = SentinelHubRequest(
    evalscript=evalscript_clm,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L1C,
            time_interval=('2020-06-12', '2020-06-13'),
        )
    ],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.PNG)
    ],
    bbox=Gjao_bbox,
    size=Gjao_size,
    config=config
)

# %%
data_with_cloud_mask = request_true_color.get_data()

# %%
plot_image(data_with_cloud_mask[0], factor=1/255)

# %%
request_true_color = SentinelHubRequest(
    evalscript=evalscript_true_color,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L1C,
            time_interval=('2020-06-01', '2020-06-30'),
            mosaicking_order='leastCC'
        )
    ],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.PNG)
    ],
    bbox=Gjao_bbox,
    size=Gjao_size,
    config=config
)

# %%
plot_image(request_true_color.get_data()[0], factor=1/300, clip_range=(0,1))

# %%
import imagecodecs

# %%
evalscript_all_bands = """
    //VERSION=3
    function setup() {
        return {
            input: [{
                bands: ["B01","B02","B03","B04","B05","B06","B07","B08","B8A","B09","B10","B11","B12"],
                units: "DN"
            }],
            output: {
                bands: 13,
                sampleType: "INT16"
            }
        };
    }

    function evaluatePixel(sample) {
        return [sample.B01,
                sample.B02,
                sample.B03,
                sample.B04,
                sample.B05,
                sample.B06,
                sample.B07,
                sample.B08,
                sample.B8A,
                sample.B09,
                sample.B10,
                sample.B11,
                sample.B12];
    }
"""

request_all_bands = SentinelHubRequest(
    evalscript=evalscript_all_bands,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L1C,
            time_interval=('2020-06-01', '2020-06-30'),
            mosaicking_order='leastCC'
    )],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.TIFF)
    ],
    bbox=Gjao_bbox,
    size=Gjao_size,
    config=config
)

# %%
all_bands_response = request_all_bands.get_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_161/3432519146.py in ?()
# ----> 1 all_bands_response = request_all_bands.get_data()
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/base.py in ?(self, save_data, redownload, data_filter, max_threads, decode_data, raise_download_errors, show_progress)
#     105         :return: requested images as numpy arrays, where each array corresponds to a single acquisition and has
#     106             shape ``[height, width, channels]``.
#     107         """
#     108         self._preprocess_request(save_data, True)
# --> 109         return self._execute_data_download(
#     110             data_filter,
#     111             redownload,
#     112             max_threads,
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/base.py in ?(self, data_filter, redownload, max_threads, raise_download_errors, decode_data, show_progress)
#     179
#     180         client = self.download_client_class(
#     181             redownload=redownload, raise_download_errors=raise_download_errors, config=self.config
#     182         )
# --> 183         data_list = client.download(
#     184             filtered_download_list, max_threads=max_threads, decode_data=decode_data, show_progress=show_progress
#     185         )
#     186
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/download/sentinelhub_client.py in ?(self, *args, **kwargs)
#      60         self.lock = Lock()
#      61         try:
#      62             return super().download(*args, **kwargs)
#      63         finally:
# ---> 64             self.lock = None
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/download/client.py in ?(self, download_requests, max_threads, decode_data, show_progress)
#      98             with progress_context as progress_bar:
#      99                 for future in as_completed(download_list):
#     100                     try:
#     101                         results[future_order[future]] = future.result()
# --> 102                     except DownloadFailedException as download_exception:
#     103                         if self.raise_download_errors:
#     104                             raise download_exception
#     105
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?(self, timeout)
#     459                 else:
#     460                     raise TimeoutError()
#     461         finally:
#     462             # Break a reference cycle with the exception in self._exception
# --> 463             self = None
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?(self)
#     402             try:
#     403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
# --> 406                 self = None
#     407         else:
#     408             return self._result
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/thread.py in ?(self)
#      58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#      61             # Break a reference cycle with the exception 'exc'
# ---> 62             self = None
#      63         else:
#      64             self.future.set_result(result)
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/download/client.py in ?(self, request)
#     115     def _single_download_decoded(self, request: DownloadRequest) -> Any:
#     116         """Downloads a response and decodes it into data. By decoding a single response"""
#     117         response = self._single_download(request)
# --> 118         return None if response is None else response.decode()
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/download/models.py in ?(self)
#     244     def decode(self) -> Any:
#     245         """Decodes binary data into a Python object."""
# --> 246         return decode_data(self.content, data_type=self.response_type)
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/decoding.py in ?(response_content, data_type)
#      34         return json.loads(response_text)
#      35     if data_type is MimeType.TAR:
#      36         return decode_tar(response_content)
#      37     if MimeType.is_image_format(data_type):
# ---> 38         return decode_image(response_content, data_type)
#      39     if data_type is MimeType.XML or data_type is MimeType.GML or data_type is MimeType.SAFE:
#      40         return ElementTree.fromstring(response_content)
#      41
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/sentinelhub/decoding.py in ?(data, image_type)
#      59     :raises: ImageDecodingError
#      60     """
#      61     bytes_data = BytesIO(data)
#      62     if image_type is MimeType.TIFF:
# ---> 63         image = tiff.imread(bytes_data)
#      64     elif image_type is MimeType.JP2:
#      65         image = decode_jp2_image(bytes_data)
#      66     else:
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1079                     )
#    1080                     if selection is None:
#    1081                         return store
#    1082                     return zarr_selection(store, selection)
# -> 1083                 return tif.asarray(
#    1084                     key=key,
#    1085                     series=series,
#    1086                     level=level,
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers)
#    4268         elif len(pages) == 1:
#    4269             page0 = pages[0]
#    4270             if page0 is None:
#    4271                 raise ValueError('page is None')
# -> 4272             result = page0.asarray(out=out, maxworkers=maxworkers)
#    4273         else:
#    4274             result = stack_pages(pages, out=out, maxworkers=maxworkers)
#    4275
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, out, squeeze, lock, maxworkers)
#    8989                     ]
#    8990                 # except IndexError:
#    8991                 #     pass  # corrupted file, for example, with too many strips
#    8992
# -> 8993             for _ in self.segments(
#    8994                 func=func,
#    8995                 lock=lock,
#    8996                 maxworkers=maxworkers,
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, lock, maxworkers, func, sort, _fullsize)
#    8803                     lock=lock,
#    8804                     sort=sort,
#    8805                     flat=False,
#    8806                 ):
# -> 8807                     yield from executor.map(decode, segments)
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?()
#     621                         yield _result_or_cancel(fs.pop())
#     622                     else:
#     623                         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#     624             finally:
# --> 625                 for future in fs:
#     626                     future.cancel()
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?(***failed resolving arguments***)
#     320         finally:
#     321             fut.cancel()
#     322     finally:
#     323         # Break a reference cycle with the exception in self._exception
# --> 324         del fut
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?(self, timeout)
#     459                 else:
#     460                     raise TimeoutError()
#     461         finally:
#     462             # Break a reference cycle with the exception in self._exception
# --> 463             self = None
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/_base.py in ?(self)
#     402             try:
#     403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
# --> 406                 self = None
#     407         else:
#     408             return self._result
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/concurrent/futures/thread.py in ?(self)
#      58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#      61             # Break a reference cycle with the exception 'exc'
# ---> 62             self = None
#      63         else:
#      64             self.future.set_result(result)
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(args, decodeargs, decode)
#    8781             def decode(args, decodeargs=decodeargs, decode=keyframe.decode):
# -> 8782                 return func(decode(*args, **decodeargs))  # type: ignore
#
# /home/conda/users/78c2e9a35d8f916b51e069b3359b976953e33c4ac102d2c530b5373dd8486c9d-20240215-082503-014013-382-edcg-2023.10-01/lib/python3.10/site-packages/tifffile/tifffile.py in ?(exc, *args, **kwargs)
#    8209             def decode_raise_compression(*args, exc=str(exc)[1:-1], **kwargs):
# -> 8210                 raise ValueError(f'{exc}')
#
# ValueError: <COMPRESSION.DEFLATE: 32946> requires the 'imagecodecs' package

# %%
# Image showing the SWIR band B12
# Factor 1/1e4 due to the DN band values in the range 0-10000
# Factor 3.5 to increase the brightness
plot_image(all_bands_response[0][:, :, 12], factor=3.5/1e4, vmax=1)
